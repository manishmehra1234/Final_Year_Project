# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls /content/drive/MyDrive/comb_biov2/
# Out:
# classes.txt  images  labels

# %%
# !ls /content/drive/MyDrive/comb_biov2/images/
# Out:
# train  val

# %%
# !ls /content/drive/MyDrive/comb_biov2/labels/
# Out:
# train  val

# %%
# !ls /content/drive/MyDrive/comb_biov2/images/val | wc -l
# Out:
# 713

# %%
# %%writefile /content/drive/MyDrive/comb_biov2/data.yaml
# train: /content/drive/MyDrive/comb_biov2/images/train
# val: /content/drive/MyDrive/comb_biov2/images/val
#
# nc: 12
#
# names: ["syringes","tweezers","mask","gloves","gauze","syringe_needles","paper_equipment","plastic_equipment","organic_wastes","metal_equipment","glass_equipment","body_tissue"]
# Out:
# Writing /content/drive/MyDrive/comb_biov2/data.yaml

# %%
# !ls /content/drive/MyDrive/comb_biov2/images/val | wc -l
# Out:
# 713

# %%
# !ls /content/drive/MyDrive/comb_biov2/labels/val | wc -l
# Out:
# 713

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 23.6 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO

model = YOLO('yolov8n.pt')

model.train(
    data='/content/drive/MyDrive/comb_biov2/data.yaml',
    epochs=60,
    imgsz=640,
    batch=8
)
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# Ultralytics 8.4.46 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...

# %%
# !cp /content/runs/detect/train/weights/best.pt /content/drive/MyDrive/comb_biov2/best.pt

# %%
# !ls /content/drive/MyDrive/comb_biov2/
# Out:
# best.pt  classes.txt  data.yaml  images  labels

# %%
# !ls /content/drive/MyDrive/comb_biov2/
# Out:
# best.pt  classes.txt  data.yaml  images  labels

# %%
# !find / -name "best.pt" 2>/dev/null

# %%
# !find / -name "last.pt" 2>/dev/null

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !find /content/drive -name "*.pt"
# Out:
# /content/drive/MyDrive/yolo_runs/biomedical_waste/weights/epoch0.pt
# /content/drive/MyDrive/yolo_runs/biomedical_waste/weights/epoch5.pt
# /content/drive/MyDrive/yolo_runs/biomedical_waste/weights/epoch10.pt
# /content/drive/MyDrive/yolo_runs/biomedical_waste/weights/epoch15.pt
# /content/drive/MyDrive/yolo_runs/biomedical_waste/weights/epoch20.pt
# /content/drive/MyDrive/yolo_runs/biomedical_waste/weights/epoch25.pt
# /content/drive/MyDrive/yolo_runs/biomedical_waste/weights/best.pt
# /content/drive/MyDrive/yolo_runs/biomedical_waste/weights/last.pt
# /content/drive/MyDrive/comb_biov2/best.pt

# %%
from ultralytics import YOLO

# Load your previously trained weights
model = YOLO('/content/drive/MyDrive/yolo_runs/biomedical_waste/weights/last.pt')

# Train ~40 more epochs to make total training roughly 100 epochs
model.train(
    data='/content/drive/MyDrive/comb_biov2/data.yaml',
    epochs=40,
    imgsz=640,
    batch=8,
    project='/content/drive/MyDrive/yolo_runs',
    name='biomedical_waste_resume'
)
# Out:
# Ultralytics 8.4.47 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-301eb447-9a16-45cb-bc61-1376836fabd5" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-301eb447-9a16-45cb-bc61-1376836fabd5">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from ultralytics import YOLO

model = YOLO('/content/drive/MyDrive/yolo_runs/biomedical_waste_resume/weights/best.pt')

results = model.predict(
    source='.',
    conf=0.25,
    save=True
)
# Out:
# image 1/21 /content/18.png: 576x640 1 syringes, 1 gloves, 58.7ms
# image 2/21 /content/21.png: 608x640 6 plastic_equipments, 55.2ms
# image 3/21 /content/46.jpeg: 608x640 1 gauze, 36.3ms
# image 4/21 /content/51.jpeg: 640x544 1 gauze, 58.3ms
# image 5/21 /content/IMG_6262_JPG.rf.8c00e7988f0549d30493e1e141deeb4e.jpg: 640x640 1 glass_equipment, 38.0ms
# image 6/21 /content/IMG_6263_JPG.rf.25fa9d84c0ea51568153b24c7428af87.jpg: 640x640 1 glass_equipment, 36.8ms
# image 7/21 /content/IMG_6300_JPG.rf.dc2a74598a1f3ec6b13db81bdf3ac06e.jpg: 640x640 1 gloves, 24.3ms
# LINE_ALBUM_191266_-_160_jpg.rf.40591f9ababd31c363100055c14100ad.jpg
# LINE_ALBUM_191266_๒๓๑๒๑๙_16.jpg
# LINE_ALBUM_191266_๒๓๑๒๑๙_220.jpg
# LINE_ALBUM_-_-_54_jpg.rf.b24a4c7397f9ffd41e8cd88e21950d13.jpg
# LINE_ALBUM_-_-_55_jpg.rf.4c7fd044a53ea6f5954488ebf3d7c370.jpg

# %%
# !ls /content/runs/detect/predict
# Out:
# 18.jpg
# 21.jpg
# 46.jpg
# 51.jpg
# IMG_6262_JPG.rf.8c00e7988f0549d30493e1e141deeb4e.jpg
# IMG_6263_JPG.rf.25fa9d84c0ea51568153b24c7428af87.jpg
# IMG_6300_JPG.rf.dc2a74598a1f3ec6b13db81bdf3ac06e.jpg
# IMG_6321.jpg
# IMG_6341_JPG.rf.0b8b9757cb4599d32b33bf770ea53dd9.jpg
# IMG_6364_JPG.rf.db8c0b5cb936cb55f23954323649dfce.jpg
# IMG_6482_JPG.rf.2a7b3a7c24acc80dcfe57782d1815c15.jpg
# IMG_6521_JPG.rf.f7ec738923471b05f7894b4b384aa472.jpg
# IMG_6624_JPG.rf.14ce6f41a5f9b3267764715d67174e30.jpg
# IMG_6745.jpg
# IMG_6808_JPG.rf.bd7b754e83188628140d14046c583a55.jpg
# IMG_6843_JPG.rf.eb54225e5d6292749c162c8c6285b558.jpg
# LINE_ALBUM_191266_-_160_jpg.rf.40591f9ababd31c363100055c14100ad.jpg
# LINE_ALBUM_191266_๒๓๑๒๑๙_16.jpg
# LINE_ALBUM_191266_๒๓๑๒๑๙_220.jpg
# LINE_ALBUM_-_-_54_jpg.rf.b24a4c7397f9ffd41e8cd88e21950d13.jpg
# LINE_ALBUM_-_-_55_jpg.rf.4c7fd044a53ea6f5954488ebf3d7c370.jpg

# %%
from IPython.display import Image, display

display(Image(filename='/content/runs/detect/predict/18.jpg'))

# %%
display(Image(filename='/content/runs/detect/predict/IMG_6321.jpg'))

# %%
display(Image(filename='/content/runs/detect/predict/46.jpg'))

# %%
display(Image(filename='/content/runs/detect/predict/21.jpg'))

# %%
display(Image(filename='/content/runs/detect/predict/LINE_ALBUM_-_-_55_jpg.rf.4c7fd044a53ea6f5954488ebf3d7c370.jpg'))

# %%
display(Image(filename='/content/runs/detect/predict/IMG_6808_JPG.rf.bd7b754e83188628140d14046c583a55.jpg'))

# %%
from IPython.display import Image, display

display(Image('/content/drive/MyDrive/yolo_runs/biomedical_waste_resume/results.png'))

# %%
display(Image('/content/drive/MyDrive/yolo_runs/biomedical_waste_resume/confusion_matrix.png'))

# %%
display(Image(filename='/content/drive/MyDrive/yolo_runs/biomedical_waste_resume/BoxPR_curve.png'))

# %%
display(Image(filename='/content/drive/MyDrive/yolo_runs/biomedical_waste_resume/BoxP_curve.png'))

# %%
display(Image(filename='/content/drive/MyDrive/yolo_runs/biomedical_waste_resume/BoxR_curve.png'))

# %%
display(Image(filename='/content/drive/MyDrive/yolo_runs/biomedical_waste_resume/BoxF1_curve.png'))

# %%
# !ls /content/drive/MyDrive/yolo_runs/biomedical_waste_resume/weights
# Out:
# best.pt  last.pt
